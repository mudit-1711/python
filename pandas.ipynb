# %%
import pandas as pd

# %%
df = pd.read_csv('ipl_data.csv')
#df.head(2)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1243 entries, 0 to 1242
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   date             1243 non-null   str
#  1   season           1243 non-null   str
#  2   city             1243 non-null   str
#  3   venue            1243 non-null   str
#  4   team1            1243 non-null   str
#  5   team2            1243 non-null   str
#  6   toss_winner      1243 non-null   str
#  7   toss_decision    1243 non-null   str
#  8   team1_runs       1243 non-null   int64
#  9   team1_wickets    1243 non-null   int64
#  10  team2_runs       1243 non-null   int64
#  11  team2_wickets    1243 non-null   int64
#  12  winner           1218 non-null   str
#  13  result_type      1243 non-null   str
#  14  win_by_runs      1243 non-null   int64
#  15  win_by_wickets   1243 non-null   int64
#  16  player_of_match  1234 non-null   str
#  17  match_referee    1243 non-null   str
# ...

# %%
df.describe()
# Out:
#         team1_runs  team1_wickets   team2_runs  team2_wickets  win_by_runs  \
# count  1243.000000    1243.000000  1243.000000    1243.000000  1243.000000
# mean    165.851167       5.956557   157.349155       5.873693    13.932422
# std      35.490847       2.309341    34.613073       2.646538    23.861556
# min       2.000000       0.000000     0.000000       0.000000     0.000000
# 25%     144.000000       4.000000   138.000000       4.000000     0.000000
# 50%     165.000000       6.000000   160.000000       6.000000     0.000000
# 75%     189.000000       8.000000   179.000000       8.000000    20.000000
# max     287.000000      10.000000   265.000000      12.000000   146.000000
#
#        win_by_wickets  overs_limit         year
# count     1243.000000       1243.0  1243.000000
# mean         3.276750         20.0  2017.242156
# std          3.358216          0.0     5.550682
# min          0.000000         20.0  2008.000000
# 25%          0.000000         20.0  2012.000000
# ...

# %%
print(df['team1_runs'])
# Out:
# 0        82
# 1       207
# 2       132
# 3       112
# 4       165
#        ...
# 1238    203
# 1239    254
# 1240    243
# 1241    214
# 1242    155
# Name: team1_runs, Length: 1243, dtype: int64

# %%
import pandas as pd
df=pd.read_csv(r'D:\python\datasets\area_prices_monthly.csv')

# %%
df.head()
# Out:
#   year_month      community           zone  is_freehold  \
# 0    2020-01  Palm Jumeirah  Palm Jumeirah         True
# 1    2020-02  Palm Jumeirah  Palm Jumeirah         True
# 2    2020-03  Palm Jumeirah  Palm Jumeirah         True
# 3    2020-04  Palm Jumeirah  Palm Jumeirah         True
# 4    2020-05  Palm Jumeirah  Palm Jumeirah         True
#
#    secondary_price_per_sqft_usd  secondary_price_per_m2_usd  \
# 0                           662                        7126
# 1                           666                        7167
# 2                           703                        7564
# 3                           651                        7002
# 4                           637                        6852
#
#    offplan_price_per_sqft_usd  rental_price_per_sqft_annual_usd  \
# 0                       752.0                                43
# 1                       728.0                                43
# 2                       762.0                                46
# ...

# %%
df.tail()
# Out:
#      year_month   community      zone  is_freehold  \
# 6379    2025-12  Jumeirah 3  Jumeirah         True
# 6380    2026-01  Jumeirah 3  Jumeirah         True
# 6381    2026-02  Jumeirah 3  Jumeirah         True
# 6382    2026-03  Jumeirah 3  Jumeirah         True
# 6383    2026-04  Jumeirah 3  Jumeirah         True
#
#       secondary_price_per_sqft_usd  secondary_price_per_m2_usd  \
# 6379                           813                        8748
# 6380                           832                        8959
# 6381                           823                        8854
# 6382                           816                        8779
# 6383                           846                        9106
#
#       offplan_price_per_sqft_usd  rental_price_per_sqft_annual_usd  \
# 6379                       891.0                                53
# 6380                       912.0                                54
# 6381                       908.0                                53
# ...

# %%
print(df)
# Out:
#      year_month      community           zone  is_freehold  \
# 0       2020-01  Palm Jumeirah  Palm Jumeirah         True
# 1       2020-02  Palm Jumeirah  Palm Jumeirah         True
# 2       2020-03  Palm Jumeirah  Palm Jumeirah         True
# 3       2020-04  Palm Jumeirah  Palm Jumeirah         True
# 4       2020-05  Palm Jumeirah  Palm Jumeirah         True
# ...         ...            ...            ...          ...
# 6379    2025-12     Jumeirah 3       Jumeirah         True
# 6380    2026-01     Jumeirah 3       Jumeirah         True
# 6381    2026-02     Jumeirah 3       Jumeirah         True
# 6382    2026-03     Jumeirah 3       Jumeirah         True
# 6383    2026-04     Jumeirah 3       Jumeirah         True
#
#       secondary_price_per_sqft_usd  secondary_price_per_m2_usd  \
# 0                              662                        7126
# 1                              666                        7167
# 2                              703                        7564
# ...

# %%
print(df['community'])
# Out:
# 0       Palm Jumeirah
# 1       Palm Jumeirah
# 2       Palm Jumeirah
# 3       Palm Jumeirah
# 4       Palm Jumeirah
#             ...
# 6379       Jumeirah 3
# 6380       Jumeirah 3
# 6381       Jumeirah 3
# 6382       Jumeirah 3
# 6383       Jumeirah 3
# Name: community, Length: 6384, dtype: object

# %%
df.drop(columns=['n_listings_secondary'],inplace=True)

# %%
print(df.columns)
# Out:
# Index(['year_month', 'community', 'zone', 'secondary_price_per_sqft_usd',
#        'secondary_price_per_m2_usd', 'offplan_price_per_sqft_usd',
#        'rental_price_per_sqft_annual_usd', 'n_listings_offplan',
#        'n_listings_rental', 'cbuae_base_rate_pct', 'avg_mortgage_rate_pct'],
#       dtype='object')

# %%
df.head()
# Out:
#   year_month      community           zone  secondary_price_per_sqft_usd  \
# 0    2020-01  Palm Jumeirah  Palm Jumeirah                           662
# 1    2020-02  Palm Jumeirah  Palm Jumeirah                           666
# 2    2020-03  Palm Jumeirah  Palm Jumeirah                           703
# 3    2020-04  Palm Jumeirah  Palm Jumeirah                           651
# 4    2020-05  Palm Jumeirah  Palm Jumeirah                           637
#
#    secondary_price_per_m2_usd  offplan_price_per_sqft_usd  \
# 0                        7126                       752.0
# 1                        7167                       728.0
# 2                        7564                       762.0
# 3                        7002                       727.0
# 4                        6852                       676.0
#
#    rental_price_per_sqft_annual_usd  n_listings_offplan  n_listings_rental  \
# 0                                43                  72                111
# ...

# %%
import pandas as pd 
df=pd.read_csv(r'D:\python\datasets\doremon dataset\character_list.csv')

# %%
df.head()
# Out:
#   Orginal Name       English Name  Gender    Species      Age  \
# 0        ドラえもん           Doraemon   Robot  Robot Cat  Unknown
# 1       野比 のび太        Nobita Nobi    Male      Human       10
# 2         源 静香   Shizuka Minamoto  Female      Human       10
# 3         剛田 武  Gian (Takeo Goda)    Male      Human       11
# 4       骨川 スネ夫     Suneo Honekawa    Male      Human       10
#
#          Birthd Date         first_appearance  Role          Occupation  \
# 0  September 3, 2112  Doraemon's Birth (1979)  Main  Nobita's caretaker
# 1           August 7                Episode 1  Main  Elementary Student
# 2         October 20                Episode 1  Main  Elementary Student
# 3            June 15                Episode 1  Main  Elementary Student
# 4        February 29                Episode 1  Main  Elementary Student
#
#                   Personality                     Likes  \
# 0     Kind, Helpful, Cowardly  Dorayaki, Helping Nobita
# ...

# %%
print(df['English Name'])
# Out:
# 0                       Doraemon
# 1                    Nobita Nobi
# 2               Shizuka Minamoto
# 3              Gian (Takeo Goda)
# 4                 Suneo Honekawa
#                  ...
# 95                         Puchi
# 96                           Lon
# 97                           Mew
# 98                     Dora-Taro
# 99    Nobita's Great-Grandfather
# Name: English Name, Length: 100, dtype: object

# %%
name = df['English Name']

# %%
eng_name=[n for n in name ]
print(eng_name)
# Out:
# ['Doraemon', 'Nobita Nobi', 'Shizuka Minamoto', 'Gian (Takeo Goda)', 'Suneo Honekawa', 'Dorami', 'Tamako Nobi', 'Nobisuke Nobi', "Gian's Mother", 'Dekisugi Hidetoshi', "Jaiko (Gian's Sister)", "Suneo's Mother", 'Teacher (Mr. Sakurada)', 'Wang Dora (Dora The Kid)', 'Piisuke (Little Dino)', 'Lulu', "Nobiko (Future Nobita's Daughter)", 'Lord Zandar (Antagonist)', 'Mii-chan', 'Dorarinho', 'Time Patrol Officers', "Sewashi (Nobita's Descendant)", "Nobisuke (Child Nobita's Dad)", "Tamako (Child Nobita's Mom)", 'Dora the Kid', 'Kaminari-san', 'Doraemon (1st Gen)', 'Miyo', 'Ganta', 'Mr. Chao', 'Sarah', 'Captain Silver', 'Burikin', 'Kukuru', 'Chiruchiru', 'Zona', 'Papi', 'Moa', 'Dark', 'Nonbiri', 'Romi', 'Bonbon', 'Pururu', 'Gatcho', 'Palo', 'Zolo', 'Pirika', 'Dok', 'Atoi', 'Big Light', 'Mini-Doras', 'Time Machine', 'Evil Nobita', 'Future Doraemon', 'Mr. Onion', 'Tsuchinoko', 'Nimuge', 'Puppet', 'Marron', 'Yuki', 'Robo-Dog', 'Kaneru', 'Garigari', 'Pampa', 'Evil Nobiko', 'Dorando', 'Chobin', 'P
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Orginal Name             100 non-null    object
#  1   English Name             100 non-null    object
#  2   Gender                   99 non-null     object
#  3   Species                  100 non-null    object
#  4   Age                      100 non-null    object
#  5   Birthd Date              100 non-null    object
#  6   first_appearance         100 non-null    object
#  7   Role                     100 non-null    object
#  8   Occupation               100 non-null    object
#  9   Personality              100 non-null    object
#  10  Likes                    100 non-null    object
#  11  Dislike                  100 non-null    object
#  12  Best Friends             77 non-null     object
#  13  Rivals                   26 non-null     object
# ...

# %%
print(df['Age'],df['English Name'])
# Out:
# 0     Unknown
# 1          10
# 2          10
# 3          11
# 4          10
#        ...
# 95          6
# 96         12
# 97    Unknown
# 98    Unknown
# 99         70
# Name: Age, Length: 100, dtype: object 0                       Doraemon
# 1                    Nobita Nobi
# 2               Shizuka Minamoto
# 3              Gian (Takeo Goda)
# 4                 Suneo Honekawa
#                  ...
# 95                         Puchi
# 96                           Lon
# 97                           Mew
# 98                     Dora-Taro
# 99    Nobita's Great-Grandfather
# Name: English Name, Length: 100, dtype: object

# %%
print(df.shape)
# Out:
# (100, 20)

# %%
df.describe()
# Out:
#        Orginal Name English Name Gender Species      Age Birthd Date  \
# count           100          100     99     100      100         100
# unique          100          100      4      18       18          14
# top           ドラえもん     Doraemon   Male   Human  Unknown     Unknown
# freq              1            1     59      51       36          84
#
#                                first_appearance              Role  \
# count                                       100               100
# unique                                       49                11
# top     Doraemon: Nobita's Robot Kingdom (2002)  Movie Supporting
# freq                                          9                53
#
#                 Occupation        Personality        Likes Dislike  \
# count                  100                100          100     100
# unique                  72                 98           93      90
# top     Elementary Student  Genius, Shy, Kind  Gold, Power     War
# ...

# %%
df.head(20)
# Out:
#    Orginal Name                       English Name  Gender    Species  \
# 0         ドラえもん                           Doraemon   Robot  Robot Cat
# 1        野比 のび太                        Nobita Nobi    Male      Human
# 2          源 静香                   Shizuka Minamoto  Female      Human
# 3          剛田 武                  Gian (Takeo Goda)    Male      Human
# 4        骨川 スネ夫                     Suneo Honekawa    Male      Human
# 5           ドラミ                             Dorami  Female  Robot Cat
# 6         野比 玉子                        Tamako Nobi  Female      Human
# 7        野比 のび助                      Nobisuke Nobi    Male      Human
# 8       ジャイアンの母                      Gian's Mother  Female      Human
# 9        出木杉 英才                 Dekisugi Hidetoshi    Male      Human
# 10         ジャイ子              Jaiko (Gian's Sister)  Female      Human
# 11        スネ夫の母                     Suneo's Mother  Female      Human
# ...

# %%
df.tail(20)
# Out:
#    Orginal Name                English Name  Gender    Species      Age  \
# 80         ミッチー                      Mitchi    Male      Human       10
# 81          ドラ坊                     Dora-Bo    Male  Robot Cat  Unknown
# 82          サニー                       Sunny  Female      Human       10
# 83      ドクター・クロ                    Dr. Kuro    Male      Human       50
# 84          プリン                        Prin  Female      Alien        8
# 85          ロック                        Lock    Male      Human       12
# 86         マービー                       Marvy    Male      Human       11
# 87           ミコ                        Miko  Female      Human       10
# 88          ドラ山                   Dora-Yama    Male      Robot  Unknown
# 89          チップ                        Chip    Male      Robot  Unknown
# 90           リル                         Lil  Female      Alien       10
# 91         ゴンスケ                     Gonsuke    Male      Human       10
# ...
