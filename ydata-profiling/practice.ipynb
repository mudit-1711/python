# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
ipl = pd.read_csv(r"D:\python\datasets\ipl_data.csv")
netflix=pd.read_csv(r"D:\python\datasets\netflix_titles.csv")

# %%
ipl_report = ProfileReport(ipl)
ipl_report.to_file(output_file='ipl.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
netflix_report = ProfileReport(netflix)
netflix_report.to_file(output_file='netflix.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
